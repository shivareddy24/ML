# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 2.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.8 MB 2.1 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.8 MB 2.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.8 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/9.8 MB 2.3 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.8 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 3.7/9.8 MB 2.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.8 MB 2.3 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.8 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.8 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 5.2/9.8 MB 2.2 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
