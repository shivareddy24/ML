# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\k shiva prasad reddy\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\k shiva prasad reddy\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\k shiva prasad reddy\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\k shiva prasad reddy\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\k shiva prasad reddy\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\k shiva prasad reddy\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(0,100,size=(6,4)), columns=['A','B','C','D'])
print(df)
print("end=")
df.set_index('A',inplace=True)
print(df)
# Out:
#     A   B   C   D
# 0  27   4  78  85
# 1  70  79  24  44
# 2  50  98  39  58
# 3  44  36   7   0
# 4  72   7  54  50
# 5  98  94  58  55
# end=
#      B   C   D
# A
# 27   4  78  85
# 70  79  24  44
# 50  98  39  58
# 44  36   7   0
# 72   7  54  50
# 98  94  58  55

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(0,100,size=(3,3)), columns=['A','B','C'],index=['X','Y','Z'])
print(df)
print()

print(df['B']['Y'])
# Out:
#     A   B   C
# X  65  93  47
# Y   7  94  22
# Z  24  49  62
#
# 94

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(0,100,size=(3,3)), columns=['A','B','C'],index=['X','Y','Z'])
print(df)
print()

print(df['B']['Y'])
# Out:
#     A   B   C
# X  84   3  40
# Y  14  41  22
# Z  98  72  35
#
# 41
