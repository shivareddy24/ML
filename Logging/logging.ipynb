# %%
import logging

# %%
def basic_logging() :
      logging.basicConfig(
      filename = "app.log",
      level = logging.INFO
    )
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
basic_logging()
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
def logger_handlers():
    logger = logging.getLogger("my_logger")
    logger.setLevel(logging.DEBUG)
    logger.handlers.clear()

    handler = logging.FileHandler("app.log")
    handler1 = logging.StreamHandler()

    handler.setLevel(logging.INFO)
    handler1.setLevel(logging.INFO)

    formatter = logging.Formatter('%(lineno)d-%(asctime)s-%(name)s-%(levelname)s-%(message)s')
    handler.setFormatter(formatter)
    handler1.setFormatter(formatter)

    logger.addHandler(handler)
    logger.addHandler(handler1)

    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

logger_handlers()
# Out:
# DEBUG:my_logger:This is a debug message
# 20-2026-08-08 17:38:24,470-my_logger-INFO-This is an info message
# INFO:my_logger:This is an info message
# 21-2026-08-08 17:38:24,473-my_logger-WARNING-This is a warning message
# WARNING:my_logger:This is a warning message
# 22-2026-08-08 17:38:24,475-my_logger-ERROR-This is an error message
# ERROR:my_logger:This is an error message
# 23-2026-08-08 17:38:24,478-my_logger-CRITICAL-This is a critical message
# CRITICAL:my_logger:This is a critical message

# %%
def logger_formatting():
    logger = logging.getLogger("my_logger")
    logger.setLevel(logging.DEBUG)
    logger.handlers.clear()
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO)

    formatting = logging.Formatter(' %(asctime)s - %(name)s - %(levelname)s - %(message)s')
    console_handler.setFormatter(formatting)

    logger.addHandler(console_handler)

    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

logger_formatting()
# Out:
# DEBUG:my_logger:This is a debug message
#  2026-08-08 17:38:46,747 - my_logger - INFO - This is an info message
# INFO:my_logger:This is an info message
#  2026-08-08 17:38:46,751 - my_logger - WARNING - This is a warning message
# WARNING:my_logger:This is a warning message
#  2026-08-08 17:38:46,754 - my_logger - ERROR - This is an error message
# ERROR:my_logger:This is an error message
#  2026-08-08 17:38:46,758 - my_logger - CRITICAL - This is a critical message
# CRITICAL:my_logger:This is a critical message
