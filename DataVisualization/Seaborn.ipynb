# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from seaborn) (2.5.1)
# Requirement already satisfied: pandas>=1.2 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\K Shiva Prasad Reddy\OneDrive\Desktop\python\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('Scatter plot of total bill vs tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
sns.lineplot(x='total_bill',y='tip',data=tips)
plt.title('Line plot of tip vs total bill')
# Out:
# Text(0.5, 1.0, 'Line plot of tip vs total bill')

# %%
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar plot of total bill by day')
# Out:
# Text(0.5, 1.0, 'Bar plot of total bill by day')

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title('Box plot of total bill by day')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
plt.title('Violin plot of total bill by day')
# Out:
# Text(0.5, 1.0, 'Violin plot of total bill by day')

# %%
sns.histplot(tips['total_bill'], bins=20, kde=True)
plt.title('Histogram of total bill')
# Out:
# Text(0.5, 1.0, 'Histogram of total bill')

# %%
sns.pairplot(tips)

# %%
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heatmap of correlation matrix')
# Out:
# Text(0.5, 1.0, 'Heatmap of correlation matrix')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df = pd.read_csv('data-export.csv')
data_df.head()
# Out:
#          Date       Product  Category Region  Units_Sold  Revenue  \
# 0  2025-01-01     Desk Lamp      Home  North           6   250.02
# 1  2025-01-02  Throw Pillow      Home   East          12   355.32
# 2  2025-01-03  Throw Pillow      Home   East          22   453.42
# 3  2025-01-04         Jeans  Clothing   East          38  2202.48
# 4  2025-01-05     Olive Oil      Food   East          21   187.49
#
#    Discount_Pct  Rating
# 0           7.4     1.6
# 1           1.3     4.7
# 2          31.3     2.0
# 3           3.4     2.8
# 4          25.6     2.2

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product',y='Revenue',data=data_df)
plt.title("bargraph of Product vs Revenue in data_df")
# Out:
# Text(0.5, 1.0, 'bargraph of Product vs Revenue in data_df')
