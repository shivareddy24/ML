# %%
import math
print(math.sqrt(25))
print(math.sin(radians(90)))
# Out:
# 5.0
# 1.0

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-07-27 20:00:23.911517

# %%
from random import randint

print(randint(1,100))
# Out:
# 60

# %%
import math
print(math.sqrt(16))
print(math.pow(2,3))
# Out:
# 4.0
# 8.0

# %%
try:
    import maths
    print(math.pow(15,3))
except:
    print("package not found")
# Out:
# package not found

# %%
import os
os.mkdir("new_one")
print(os.listdir("."))
os.rmdir("new_one")
print(os.listdir("."))
# Out:
# ['DataStructures', 'Functions', 'Modules_Packages.ipynb', 'new_one', 'new_onee']
# ['DataStructures', 'Functions', 'Modules_Packages.ipynb', 'new_onee']

# %%
import sys
print(sys.version)
print(sys.path)
print(sys.platform)
# Out:
# 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]
# ['C:\\Program Files\\Python313\\python313.zip', 'C:\\Program Files\\Python313\\DLLs', 'C:\\Program Files\\Python313\\Lib', 'C:\\Program Files\\Python313', 'c:\\Users\\K Shiva Prasad Reddy\\OneDrive\\Desktop\\python\\.venv', '', 'c:\\Users\\K Shiva Prasad Reddy\\OneDrive\\Desktop\\python\\.venv\\Lib\\site-packages']
# win32

# %%
import math
print(math.gcd(12, 18))
print(math.factorial(5))
# Out:
# 6
# 120

# %%
import datetime as dt
print(dt.datetime.now())
today = dt.date.today()
future = today + dt.timedelta(days=100)
print(future)
# Out:
# 2026-07-27 20:22:49.004686
# 2026-11-04

# %%
from Mypackage import addition,multiply

print(addition(2, 3))
print(multiply(5, 6))
# Out:
# 5
# 30

# %%
from Mypackage import addition, multiply

print(addition(2, 3))
print(multiply(5, 6))
# Out:
# 5
# 30

# %%
from Mypackage import addition, multiply

print(addition(2, 3))  # 5
print(multiply(2, 3))
# Out:
# 5
# 6

# %%
try:
    from mypackage import non_existent_function
except ImportError as e:
    print(f"Error importing function: {e}")
# Out:
# Error importing function: No module named 'mypackage'
