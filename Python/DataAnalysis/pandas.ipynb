# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-3.0.5-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\k shiva prasad reddy\onedrive\desktop\python\.venv\lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\k shiva prasad reddy\onedrive\desktop\python\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\k shiva prasad reddy\onedrive\desktop\python\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.5-cp313-cp313-win_amd64.whl (9.8 MB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-3.0.5 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(0,100,size=(6,4)), columns=['A','B','C','D'])
print(df)
print("end=")
df.set_index('A',inplace=True)
print(df)
# Out:
#     A   B   C   D
# 0  67  62  83  28
# 1   0  70  64  14
# 2  86  90  78  57
# 3  96  65  94  96
# 4   6  48  21  48
# 5  54  24  15  55
# end=
#      B   C   D
# A
# 67  62  83  28
# 0   70  64  14
# 86  90  78  57
# 96  65  94  96
# 6   48  21  48
# 54  24  15  55

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(0,100,size=(3,3)), columns=['A','B','C'],index=['X','Y','Z'])
print(df)
print()

print(df['B']['Y'])
# Out:
#     A   B   C
# X  13   5  33
# Y  67  23   8
# Z  93  19  81
#
# 23

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(1,10, size=(5,3)),columns=['A','B','C'])
print(df)
df['D'] = df['A'] * df['B']
print("new dataframe :")
print(df)
# Out:
#    A  B  C
# 0  1  6  9
# 1  8  8  8
# 2  6  8  6
# 3  2  8  8
# 4  8  3  7
# new dataframe :
#    A  B  C   D
# 0  1  6  9   6
# 1  8  8  8  64
# 2  6  8  6  48
# 3  2  8  8  16
# 4  8  3  7  24

# %%
import pandas as  pd
import numpy as np
df = pd.DataFrame(np.random.randint(1,20, size=(4,3)) ,columns=['A','B','C'])
print(df)   
row =  df.sum(axis=1)
col = df.sum(axis=0)
print("Sum of each row:")
print(row)
print("Sum of each column:")
print(col)
# Out:
#     A  B   C
# 0   4  5  14
# 1   9  8   6
# 2  14  5   4
# 3   8  7   7
# Sum of each row:
# 0    23
# 1    23
# 2    23
# 3    22
# dtype: int64
# Sum of each column:
# A    35
# B    25
# C    31
# dtype: int64
